# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
df = pd.merge(study_results, mouse_metadata, how = 'left', on=['Mouse ID', 'Mouse ID'])
df = df.rename(columns={'Tumor Volume (mm3)': 'Volume'})

# Display the data table for preview
df
# Out:
#      Mouse ID  Timepoint     Volume  Metastatic Sites Drug Regimen     Sex  \
# 0        b128          0  45.000000                 0    Capomulin  Female
# 1        f932          0  45.000000                 0     Ketapril    Male
# 2        g107          0  45.000000                 0     Ketapril  Female
# 3        a457          0  45.000000                 0     Ketapril  Female
# 4        c819          0  45.000000                 0     Ketapril    Male
# ...       ...        ...        ...               ...          ...     ...
# 1888     r944         45  41.581521                 2    Capomulin    Male
# 1889     u364         45  31.023923                 3    Capomulin    Male
# 1890     p438         45  61.433892                 1     Ceftamin  Female
# 1891     x773         45  58.634971                 4      Placebo  Female
# 1892     b879         45  72.555239                 2     Stelasyn  Female
#
#       Age_months  Weight (g)
# 0              9          22
# ...

# %%
# Checking the number of mice.
df['Mouse ID'].nunique()
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate = df[df.duplicated(['Mouse ID', 'Timepoint'])]

duplicate
# Out:
#      Mouse ID  Timepoint     Volume  Metastatic Sites Drug Regimen     Sex  \
# 137      g989          0  45.000000                 0     Propriva  Female
# 360      g989          5  47.570392                 0     Propriva  Female
# 681      g989         10  49.880528                 0     Propriva  Female
# 869      g989         15  53.442020                 0     Propriva  Female
# 1111     g989         20  54.657650                 1     Propriva  Female
#
#       Age_months  Weight (g)
# 137           21          26
# 360           21          26
# 681           21          26
# 869           21          26
# 1111          21          26

# %%
# Optional: Get all the data for the duplicate mouse ID.
duplicate_df = df.set_index('Mouse ID')
duplicate_df.loc['g989']
# Out:
#           Timepoint     Volume  Metastatic Sites Drug Regimen     Sex  \
# Mouse ID
# g989              0  45.000000                 0     Propriva  Female
# g989              0  45.000000                 0     Propriva  Female
# g989              5  48.786801                 0     Propriva  Female
# g989              5  47.570392                 0     Propriva  Female
# g989             10  51.745156                 0     Propriva  Female
# g989             10  49.880528                 0     Propriva  Female
# g989             15  51.325852                 1     Propriva  Female
# g989             15  53.442020                 0     Propriva  Female
# g989             20  55.326122                 1     Propriva  Female
# g989             20  54.657650                 1     Propriva  Female
# g989             25  56.045564                 1     Propriva  Female
# g989             30  59.082294                 1     Propriva  Female
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = duplicate_df.drop(['g989'])
clean_df.head()
# Out:
#           Timepoint  Volume  Metastatic Sites Drug Regimen     Sex  \
# Mouse ID
# b128              0    45.0                 0    Capomulin  Female
# f932              0    45.0                 0     Ketapril    Male
# g107              0    45.0                 0     Ketapril  Female
# a457              0    45.0                 0     Ketapril  Female
# c819              0    45.0                 0     Ketapril    Male
#
#           Age_months  Weight (g)
# Mouse ID
# b128               9          22
# f932              15          29
# g107               2          29
# a457              11          30
# c819              21          25

# %%
# Checking the number of mice in the clean DataFrame.
drop_clean_df = clean_df.reset_index()
drop_clean_df['Mouse ID'].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
drug_df = drop_clean_df.groupby(['Drug Regimen'])
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
mean = drug_df['Volume'].mean()
med = drug_df['Volume'].median()
var = drug_df['Volume'].var()
std = drug_df['Volume'].std()
sem = drug_df['Volume'].sem()

tumor_df = pd.DataFrame({
    'Mean': mean,
    'Median': med,
    'Variance': var,
    'Standard Deviation': std,
    'SEM': sem
})

tumor_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
tumor_df2 = drop_clean_df.groupby(['Drug Regimen'])['Volume'].agg(['mean', 'median', 'var', 'std', 'sem'])

tumor_df2
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Rough Work
# observations = drop_clean_df.groupby(['Drug Regimen']).count()
#observations = drop_clean_df[['Drug Regimen', 'Mouse ID']]
#observations = observations.groupby(['Drug Regimen']).count()
#observations = observations.sort_values(by=['Mouse ID'], ascending=False)

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
observations = drop_clean_df.groupby(['Drug Regimen'])['Timepoint'].count()
timepoints = observations.sort_values(ascending=False)
timepoints.plot(kind='bar')
plt.title('Observations per Drug Regimen')
plt.ylabel('# of Timepoints')
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
plt.bar(timepoints.index, timepoints.values)
plt.ylabel('Number of Timepoints')
plt.xlabel('Drug Regimen')
plt.xticks(rotation='vertical')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
sex = drop_clean_df.groupby(['Sex'])['Sex'].count()

sex.plot.pie(startangle=180, autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Sex'>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(sex, labels=('female','male'), startangle=180, autopct='%1.1f%%')
plt.ylabel('Sex')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
final_tumor = drop_clean_df.groupby(['Mouse ID'])['Timepoint'].max()
final_tumor_df = pd.DataFrame(final_tumor)

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_tumor = pd.merge(drop_clean_df, final_tumor_df, on=('Mouse ID', 'Timepoint'), how='right')
final_tumor
# Out:
#     Mouse ID  Timepoint     Volume  Metastatic Sites Drug Regimen     Sex  \
# 0       a203         45  67.973419                 2    Infubinol  Female
# 1       a251         45  65.525743                 1    Infubinol  Female
# 2       a262         45  70.717621                 4      Placebo  Female
# 3       a275         45  62.999356                 3     Ceftamin  Female
# 4       a366         30  63.440686                 1     Stelasyn  Female
# ..       ...        ...        ...               ...          ...     ...
# 243     z435         10  48.710661                 0     Propriva  Female
# 244     z578         45  30.638696                 0     Ramicane    Male
# 245     z581         45  62.754451                 3    Infubinol  Female
# 246     z795         45  65.741070                 3     Naftisol  Female
# 247     z969         45  73.867845                 4     Naftisol    Male
#
#      Age_months  Weight (g)
# 0            20          23
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
cap = []
ram = []
inf = []
cef = []


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
for index, row in final_tumor.iterrows():
    if row['Drug Regimen'] == 'Capomulin':
        ram.append(row['Volume'])
    if row['Drug Regimen'] == 'Ramicane':
        cap.append(row['Volume'])
    if row['Drug Regimen'] == 'Infubinol':
        inf.append(row['Volume'])
    if row['Drug Regimen'] == 'Ceftamin':
        cef.append(row['Volume'])
    
    # add subset 
treatment_df = pd.DataFrame({treatments[0]: cap,
                            treatments[1]: ram,
                            treatments[2]: inf,
                            treatments[3]: cef})

    
    # Determine outliers using upper and lower bounds
cap_quart = treatment_df[treatments[0]].quantile([.25, .5, .75])
cap_low = cap_quart[.25]
cap_high = cap_quart[.75]
cap_iqr = cap_high-cap_low
cap_lowerb = cap_low - (1.5*cap_iqr)
cap_upperb = cap_high + (1.5*cap_iqr)
cap_outliers = [data for data in treatment_df[treatments[0]] if data < cap_lowerb or data > cap_upperb]
# sorry for the hard code, was taking too long trying to simplfy it


ram_quart = treatment_df[treatments[1]].quantile([.25, .5, .75])
ram_low = ram_quart[.25]
ram_high = ram_quart[.75]
ram_iqr = ram_high-cap_low
ram_lowerb = ram_low - (1.5*ram_iqr)
ram_upperb = ram_high + (1.5*ram_iqr)
ram_outliers = [data for data in treatment_df[treatments[1]] if data < ram_lowerb or data > ram_upperb]

inf_quart = treatment_df[treatments[2]].quantile([.25, .5, .75])
inf_low = inf_quart[.25]
inf_high = inf_quart[.75]
inf_iqr = inf_high-cap_low
inf_lowerb = inf_low - (1.5*inf_iqr)
inf_upperb = inf_high + (1.5*inf_iqr)
inf_outliers = [data for data in treatment_df[treatments[2]] if data < inf_lowerb or data > inf_upperb]

cef_quart = treatment_df[treatments[3]].quantile([.25, .5, .75])
cef_low = cef_quart[.25]
cef_high = cef_quart[.75]
cef_iqr = cef_high-cap_low
cef_lowerb = cef_low - (1.5*cef_iqr)
cef_upperb = cef_high + (1.5*cef_iqr)
cef_outliers = [data for data in treatment_df[treatments[3]] if data < cef_lowerb or data > cef_upperb]

outliers = []
outliers.append(cap_outliers)
outliers.append(ram_outliers)
outliers.append(inf_outliers)
outliers.append(cef_outliers)
outliers
# Out:
# [[], [], [], []]

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
drug_list = [treatment_df[treatments[0]], 
             treatment_df[treatments[1]], 
             treatment_df[treatments[2]], 
             treatment_df[treatments[3]]]

fig, ax = plt.subplots(figsize = (9,7))
ax.set_title('Final Measured Tumor Volume by Drug Regimen')
ax.set_xlabel('Drug Regimen')
ax.set_ylabel('Tumor Volume (mm3)')

ax.boxplot(drug_list, 0, 'gD')
plt.xticks([1,2,3,4], treatments)
plt.savefig('Boxplot')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
line_df = drop_clean_df.loc[drop_clean_df['Mouse ID'] == 'b128',:]
line_df


x_axis = line_df['Timepoint']

y_axis = line_df['Volume']
""
plt.title('Capomulin Treatment of Mouse "b128"')

plt.plot(x_axis, y_axis, linewidth = 3, markersize = 10)
plt.xlabel('Timepoint (days)')
plt.xlabel('Tumor Volume (mm3)')

plt.savefig('Linechart')
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
cap_df = drop_clean_df.loc[drop_clean_df["Drug Regimen"] == "Capomulin",:]

cap_avg = cap_df.groupby(['Mouse ID']).mean()

plt.scatter(cap_avg['Weight (g)'],cap_avg['Volume'])
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

plt.savefig('Scatterplot')
plt.show()
# Out:
# C:\Users\MSI\AppData\Local\Temp\ipykernel_26540\1919546298.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cap_avg = cap_df.groupby(['Mouse ID']).mean()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
corr = round(st.pearsonr(cap_avg['Weight (g)'],cap_avg['Volume'])[0],2)
print(f'The correlation between mouse weight and average tumor volume is {corr}')


# From regress variable
slope = 0.9544396890241049
intercept = 21.552160532685008

line = slope * (cap_avg['Weight (g)']) + intercept

plt.scatter(cap_avg['Weight (g)'],cap_avg['Volume'])

plt.plot(cap_avg['Weight (g)'], line, 'r', label = 'y={:.2f}x+{:.2f}'.format(slope, intercept))
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

plt.legend()
plt.savefig('Linear Regression')
plt.show()
# Out:
# The correlation between mouse weight and average tumor volume is 0.84

# %%
regress = st.linregress(cap_avg['Weight (g)'],cap_avg['Volume'])
regress
# Out:
# LinregressResult(slope=0.9544396890241049, intercept=21.552160532685008, rvalue=0.8419363424694721, pvalue=1.3225722434712404e-07, stderr=0.12754359033201323, intercept_stderr=2.5909876867683455)
